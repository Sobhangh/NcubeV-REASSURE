# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3.common.evaluation import evaluate_policy
import time
import numpy as np

from torch import nn

# %%
import acc
# Out:
# `polytope` failed to import `cvxopt.glpk`.
# will use `scipy.optimize.linprog`
# Registered acc-variant-v0
# Registered acc-variant-v1
# Registered acc-variant-v2

# %%
env = gym.make("acc-variant-v1")
architecture = [dict(pi=[64, 64], vf=[64, 64])]
model = PPO("MlpPolicy", env, verbose=1,policy_kwargs={"activation_fn":nn.ReLU,"net_arch":architecture})
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\ghasob\AppData\Local\Programs\Python\Python313\Lib\site-packages\gymnasium\envs\registration.py:512: DeprecationWarning: WARN: The environment acc-variant-v1 is out of date. You should consider upgrading to version `v2`.
#   logger.deprecation(
# c:\Users\ghasob\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
model.save("ppo_acc_relu_bigger")

# %%
# Use a separate environement for evaluation
eval_env = gym.make('acc-variant-v1')

# Random Agent, before training
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# c:\Users\ghasob\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\evaluation.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward:-1375.51 +/- 609.06

# %%
model = model.learn(total_timesteps=10000)

# %%
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:2624.22 +/- 2543.53

# %%
model = model.learn(total_timesteps=190000)

# %%
# Agent, after 2,000,000 steps
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:3094.89 +/- 2165.67

# %%
model.save("ppo_acc_small_200000_steps")

# %%
model=model.learn(total_timesteps=100000)

# %%
# Agent, after 3,000,000 steps
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=1000)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:2907.62 +/- 2361.57

# %%
model.save("ppo_acc_small_300000_steps")
